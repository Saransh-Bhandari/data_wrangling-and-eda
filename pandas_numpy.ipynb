# %%
class Mapping:
    def __init__(self, iterable):
        self.items_list = []
        self.__update(iterable)

    def __update(self, iterable):
        for item in iterable:
            self.items_list.append(item)

    __update = update   # private copy of original update() method

class MappingSubclass(Mapping):

    def update(self, keys, values):
        # provides new signature for update()
        # but does not break __init__()
        for item in zip(keys, values):
            self.items_list.append(item)

# %%
m = MappingSubclass([1,2,3])
m.update([1,2,3] , [1,2,3])
dir(m)
# Out:
# ['_Mapping__update',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'items_list',
#  'update']

# %%
import os
os.system('ls')
# Out:
# Untitled1.ipynb
# Untitled.ipynb
# 0

# %%
exec(input('-'))
# Out:
# - x = 10

# %%
x
# Out:
# 10

# %%
a = 'for i in range(5):\n\tprint("hello")'
exec(a)
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
eval(a)
# Out:
# Traceback (most recent call last):
#
#   File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[14], line 1
#     eval(a)
#
#   File <string>:1
#     for i in range(5):
#     ^
# SyntaxError: invalid syntax

# %%
eval('a=5')
print(a)
# Out:
# Traceback (most recent call last):
#
#   File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[15], line 1
#     eval('a=5')
#
#   File <string>:1
#     a=5
#      ^
# SyntaxError: invalid syntax

# %%
exec('a=5')
print(a)
# Out:
# 5

# %%
for line in open("new.txt"):
    print(line, end=',')
# Out:
# wef
# ,we
# ,trh
# ,rj
# ,ytj
# ,tyjk
# ,7
# ,j64
# ,eg
# ,r
# ,ejhtrjn
# ,dsgt,

# %%
s = 'abc'
it = iter(s)
next(it)
# Out:
# 'a'

# %%
dir(iter) == dir(iter(s))
# ??
# Out:
# False

# %%
class Reverse:
    """Iterator for looping over a sequence backwards."""
    def __init__(self, data):
        self.data = data
        self.index = len(data)

    def __iter__(self):
        return self

    def __next__(self):
        if self.index == 0:
            raise StopIteration
        self.index = self.index - 1
        return self.data[self.index]
rev = Reverse('spam')
# iter(rev)
for char in iter(rev):
    print(char)
# Out:
# m
# a
# p
# s

# %%
import time
def reverse(data):
    for index in range(len(data)-1, -1, -1):
        time.sleep(1)
        yield data[index]

for char in reverse('golf'):
    print(char)
# Out:
# f
# l
# o
# g

# %%
import time
def reverse(data):
    ans = []
    for index in range(len(data)-1, -1, -1):
        time.sleep(1)
        ans.append(data[index])
    return ans

for char in reverse('golf'):
    print(char)
# Out:
# f
# l
# o
# g

# %%
sum(i*i for i in range(10))
# Out:
# 285

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/os
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
# ...

# %%
os.path
# Out:
# <module 'posixpath' from '/usr/lib/python3.8/posixpath.py'>

# %%
import sys
print(sys.argv)
# Out:
# ['/home/deq/.local/lib/python3.8/site-packages/ipykernel_launcher.py', '-f', '/home/deq/.local/share/jupyter/runtime/kernel-d22a70c0-9585-4789-bd9d-9985b79ac102.json']

# %%
import pandas as pd
import numpy as np
import pandas as pd

A = np.array(['one', 'one', 'two', 'two', 'three', 'three'])
B = np.array(['start', 'end']*3)
C = [np.random.randint(10, 99, 6)]*6
df = pd.DataFrame(zip(A, B, C), columns=['A', 'B', 'C'])
# df = pd.DataFrame({'A':A , 'B':B , 'C':C})
df.set_index(['A', 'B'], inplace=True)
df
# Out:
#                                     C
# A     B
# one   start  [67, 15, 82, 71, 19, 14]
#       end    [67, 15, 82, 71, 19, 14]
# two   start  [67, 15, 82, 71, 19, 14]
#       end    [67, 15, 82, 71, 19, 14]
# three start  [67, 15, 82, 71, 19, 14]
#       end    [67, 15, 82, 71, 19, 14]

# %%
df.shape
# Out:
# (6, 1)

# %%
import numpy as np
x = np.array([[[1,2,3] , [1,2,3] , [1,2,3]] , [[1,2,3] , [1,2,3] , [1,2,3]]])
x.shape
# Out:
# (2, 3, 3)

# %%
x[0, 0, :]
# Out:
# array([1, 2, 3])

# %%
np.array([1,2,3]).reshape(3,-1).shape
# Out:
# (3, 1)

# %%
pd.DataFrame(pd.Series(np.random.randn(5), index=["a", "b", "c", "c", "e"]))
# Out:
#           0
# a -0.113602
# b -0.054412
# c  0.457698
# c -1.631903
# e  0.702279

# %%
d = { chr(i+97) : [np.random.randint(5) for _ in range(10)] for i in range(1,5)}

# %%
df=  pd.DataFrame(d)

# %%
type(df.iloc[1:8][:])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[[1,2,9]]
# Out:
#    b  c  d  e
# 1  3  3  2  1
# 2  2  3  0  4
# 9  4  3  2  0

# %%
# t = pd.CategoricalDtype(categories=['b', 'a'  , 'd', 'c'], ordered=True , categories=['c', 'b', 'a'])
t = pd.Categorical(['a', 'b', 'c', 'd', 'a', 'b', 'c'], ordered=True,
                   categories=['c', 'b', 'a' , 'd'])
pd.Series(['a', 'b', 'a' , 'b' , 'b' , 'd' , 'c'], dtype=t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[140], line 4
#       1 # t = pd.CategoricalDtype(categories=['b', 'a'  , 'd', 'c'], ordered=True , categories=['c', 'b', 'a'])
#       2 t = pd.Categorical(['a', 'b', 'c', 'd', 'a', 'b', 'c'], ordered=True,
#       3                    categories=['c', 'b', 'a' , 'd'])
# ----> 4 pd.Series(['a', 'b', 'a' , 'b' , 'b' , 'd' , 'c'], dtype=t)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:428, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     425     index = ensure_index(index)
#     427 if dtype is not None:
# --> 428     dtype = self._validate_dtype(dtype)
#     430 if data is None:
#     431     index = index if index is not None else default_index(0)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:458, in NDFrame._validate_dtype(cls, dtype)
# ...

# %%
type(t)
# Out:
# pandas.core.dtypes.dtypes.CategoricalDtype

# %%
t.min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 t.min()
#
# AttributeError: 'CategoricalDtype' object has no attribute 'min'

# %%
c = pd.Categorical(['a', 'b', 'c', 'd', 'a', 'b', 'c'], ordered=True,
                   categories=['c', 'b', 'a'])
c.min()
# Out:
# 'c'

# %%
pd.arrays.PeriodArray(pd.PeriodIndex(['2023-01-01',
                                      '2023-01-10'], freq='M'))
# Out:
# <PeriodArray>
# ['2023-01', '2023-01']
# Length: 2, dtype: period[M]

# %%
ser = pd.Series([1, 0, 0 , None], dtype=pd.SparseDtype(dtype=int, fill_value=2))
ser
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 ser = pd.Series([1, 0, 0 , None], dtype=pd.SparseDtype(dtype=int, fill_value=2))
#       2 ser
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:509, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     507         data = data.copy()
#     508 else:
# --> 509     data = sanitize_array(data, index, dtype, copy)
#     511     manager = get_option("mode.data_manager")
#     512     if manager == "block":
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/construction.py:559, in sanitize_array(data, index, dtype, copy, allow_2d)
#     557     _sanitize_non_ordered(data)
#     558     cls = dtype.construct_array_type()
# --> 559     subarr = cls._from_sequence(data, dtype=dtype, copy=copy)
#     561 # GH#846
#     562 elif isinstance(data, np.ndarray):
#
# ...

# %%
pd.SparseDtype(dtype=float, fill_value=2)
# Out:
# Sparse[float64, 2]

# %%
ser = pd.Series([100, 0, 300], dtype=pd.SparseDtype(dtype=int, fill_value=0))
ser
# Out:
# 0    100
# 1      0
# 2    300
# dtype: Sparse[int64, 0]

# %%
ser.sparse.density
# Out:
# 0.6666666666666666

# %%
dft = pd.DataFrame(
    {
        "A": np.random.rand(3),
        "B": 1,
        "C": 0,
        "D": pd.Timestamp("20010102"),
        "E": pd.Series([1.0] * 3).astype("float32"),
        "F": False,
        "G": pd.Series([1] * 3, dtype="int8"),
    }
)
dft
# Out:
#           A  B  C          D    E      F  G
# 0  0.109911  1  0 2001-01-02  1.0  False  1
# 1  0.145796  1  0 2001-01-02  1.0  False  1
# 2  0.700097  1  0 2001-01-02  1.0  False  1

# %%
dft.astype('float32')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 dft.astype('float32')
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
dft1 = pd.DataFrame({"a": [5, 0, -1], "b": [4, 5, 6], "c": [7, 8, 9]})
dft1 = dft1.astype({"a": np.bool_, "c": np.float64})
dft1
# Out:
#        a  b    c
# 0   True  4  7.0
# 1  False  5  8.0
# 2   True  6  9.0

# %%
bool(-554645)
# Out:
# True

# %%
dft = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6], "c": [7, 8, 9]})
dft.iloc[:, 1].astype(np.uint8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[193], line 2
#       1 dft = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6], "c": [7, 8, 9]})
# ----> 2 dft.iloc[:, 1:].astype(np.uint8 , inplace=True)
#
# TypeError: astype() got an unexpected keyword argument 'inplace'

# %%
dft.iloc[:, 1] = dft.iloc[:, 1].astype(np.uint8)

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      int64
#  2   c       3 non-null      int64
# dtypes: int64(3)
# memory usage: 200.0 bytes

# %%
import datetime
datetime.datetime(2016, 3, 2 , 1 , 1, 1)
# Out:
# datetime.datetime(2016, 3, 2, 1, 1, 1)

# %%
df = pd.DataFrame(
    [
        [1, 2],
        ["a", "b"],
        [datetime.datetime(2016, 3, 2, 23 , 59, 0), datetime.datetime(2016, 3, 2, 1 , 1, 1)],
    ]
)
df = df.T

# %%
df.infer_objects().dtypes
# Out:
# 0             int64
# 1            object
# 2    datetime64[ns]
# dtype: object

# %%
df.dtypes
# Out:
# 0            object
# 1            object
# 2    datetime64[ns]
# dtype: object

# %%
m = ["1.1", 2, 3]

pd.to_numeric(m)
# Out:
# array([1.1, 2. , 3. ])

# %%
import datetime
m = ["2016-07-09", datetime.datetime(2016, 3, 2)]
pd.to_datetime(m)
# Out:
# DatetimeIndex(['2016-07-09', '2016-03-02'], dtype='datetime64[ns]', freq=None)

# %%
df[df>1]
# Out:
#      b    c    d    e
# 0  NaN  NaN  NaN  3.0
# 1  2.0  NaN  4.0  3.0
# 2  3.0  4.0  2.0  4.0
# 3  NaN  NaN  NaN  3.0
# 4  NaN  2.0  NaN  3.0
# 5  4.0  2.0  4.0  3.0
# 6  2.0  3.0  2.0  4.0
# 7  2.0  NaN  3.0  NaN
# 8  4.0  4.0  2.0  NaN
# 9  4.0  2.0  NaN  4.0

# %%
df
# Out:
#    b  c  d  e
# 0  0  1  0  3
# 1  2  0  4  3
# 2  3  4  2  4
# 3  0  1  0  3
# 4  0  2  0  3
# 5  4  2  4  3
# 6  2  3  2  4
# 7  2  0  3  0
# 8  4  4  2  0
# 9  4  2  0  4

# %%
df = pd.DataFrame(
    {
        "string": list("abc"),
        "int64": list(range(1, 4)),
        "uint8": np.arange(3, 6).astype("u1"),
        "float64": np.arange(4.0, 7.0),
        "bool1": [True, False, True],
        "bool2": [False, True, False],
        "dates": pd.date_range("now", periods=3),
        "category": pd.Series(list("ABC")).astype("category"),
    }
)


df["tdeltas"] = df.dates.diff()

# %%
df
# Out:
#   string  int64  uint8  float64  bool1  bool2                      dates  \
# 0      a      1      3      4.0   True  False 2024-02-02 14:14:55.247541
# 1      b      2      4      5.0  False   True 2024-02-03 14:14:55.247541
# 2      c      3      5      6.0   True  False 2024-02-04 14:14:55.247541
#
#   category tdeltas
# 0        A     NaT
# 1        B  1 days
# 2        C  1 days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   string    3 non-null      object
#  1   int64     3 non-null      int64
#  2   uint8     3 non-null      uint8
#  3   float64   3 non-null      float64
#  4   bool1     3 non-null      bool
#  5   bool2     3 non-null      bool
#  6   dates     3 non-null      datetime64[ns]
#  7   category  3 non-null      category
#  8   tdeltas   2 non-null      timedelta64[ns]
# dtypes: bool(2), category(1), datetime64[ns](1), float64(1), int64(1), object(1), timedelta64[ns](1), uint8(1)
# memory usage: 392.0+ bytes

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
df.select_dtypes(include=["number", "bool" , "category"], exclude=["unsignedinteger"])
# Out:
#    int64  float64  bool1  bool2 category tdeltas
# 0      1      4.0   True  False        A     NaT
# 1      2      5.0  False   True        B  1 days
# 2      3      6.0   True  False        C  1 days

# %%
dd = {"b": [1,], "a": [1,], "c": [1,]}
pd.DataFrame(dd)
# Out:
#    b  a  c
# 0  1  1  1

# %%
x = pd.Series({'x':frozenset([1,2,3]) , 'y':frozenset([1,2,3]) , 'z':frozenset([1,2,3])})

# %%
frozenset([1,2,3])
# Out:
# frozenset({1, 2, 3})

# %%
x.get('p', 1)
# Out:
# 1

# %%
s = pd.Series(np.random.randn(5), name="something")

# %%
s = s.rename("different")

# %%
s
# Out:
# 0   -1.186993
# 1   -0.249712
# 2    0.422897
# 3    1.934337
# 4    0.049330
# Name: different, dtype: float64

# %%
x = np.array([('Rex', 9, 81.0), ('Fido', 3, 27.0), (1, '1', 27.0)],
             dtype=[('random', 'U10'), ('age', 'i4'), ('weight', 'f4')])
x
# Out:
# array([('Rex', 9, 81.), ('Fido', 3, 27.), ('1', 1, 27.)],
#       dtype=[('random', '<U10'), ('age', '<i4'), ('weight', '<f4')])

# %%
x['random']
# Out:
# array(['Rex', 'Fido'], dtype='<U10')

# %%
x[1]
# Out:
# ('Fido', 3, 27.)

# %%
pd.DataFrame(x)
# Out:
#   random  age  weight
# 0    Rex    9    81.0
# 1   Fido    3    27.0

# %%
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]),
}
df = pd.DataFrame(d)
pd.DataFrame(d, columns=["two"])
# Out:
#    two
# a  1.0
# b  2.0
# c  3.0
# d  4.0

# %%
data = np.zeros((2,), dtype=[("A", "i4"), ("B", "f4"), ("C", "a10")])
data
# Out:
# array([(0, 0., b''), (0, 0., b'')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
df = pd.DataFrame.from_dict(
    dict([("A", [1, 2, 3]), ("B", [4, 5, 6])]),
    orient='index',
    columns=["one", "two", "three"],
)
df["three"] = df["one"] * df["two"]

# %%
df
# Out:
#    one  two  three
# A    1    2      2
# B    4    5     20

# %%
df.insert(1, "baar", 1)

# %%
df
# Out:
#    one  baar  bar  two  three
# A    1     1    1    2      2
# B    4     1    4    5     20

# %%
iris = pd.DataFrame(
    {
        'SepalLength':[5.1   ,      3.5      ,    1.4     ,    0.2 ],
        'SepalWidth':[4.9    ,     3.0      ,    1.4     ,    0.2  ],
        'PetalLength':[4.7     ,    3.2      ,    1.3       ,  0.2  ],
          'PetalWidth' :[4.6    ,     3.1    ,      1.5    ,     0.2 ]
}
)

(
    
    iris.query("SepalLength > 1")
    .assign(
        SepalRatio=lambda x: x.SepalWidth / x.SepalLength,
        PetalRatio=lambda x: x.PetalWidth / x.PetalLength,
    )
    .plot(kind="scatter", x="SepalRatio", y="PetalRatio")
)
# Out:
# <Axes: xlabel='SepalRatio', ylabel='PetalRatio'>

# %%
(
    
    iris.query("SepalLength > 1")
    .assign(
        SepalRatio=iris.SepalWidth / iris.SepalLength,
        PetalRatio=iris.PetalWidth / iris.PetalLength,
    )
    .plot(kind="scatter", x="SepalRatio", y="PetalRatio")
)
# Out:
# <Axes: xlabel='SepalRatio', ylabel='PetalRatio'>

# %%
np.random.randn(10, 4)
# Out:
# array([[ 0.74925218,  0.04608096, -1.78371859,  0.28016034],
#        [-0.05736877, -0.78964946,  0.48230179,  0.07739793],
#        [ 1.23898311, -1.01453313, -1.65212808, -0.51755851],
#        [-0.31985243, -1.07877327, -0.04971426, -0.86440082],
#        [-0.27970766, -0.27856508, -0.8896958 , -0.83756738],
#        [ 0.63012901,  1.44031417, -0.70323532,  0.10831225],
#        [-0.6686657 , -0.61315224, -0.87128659, -1.09149829],
#        [ 1.07258821,  1.16017228,  0.77644495, -0.45223586],
#        [ 0.23165051, -1.11823726,  1.20146143, -0.17932931],
#        [ 0.88054432, -0.27624251, -1.29364658,  0.15983343]])

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=["A", "B", "C", "D"])

df2 = pd.DataFrame(np.random.randn(7, 3), columns=["a", "b", "c"])

df + df2
# Out:
#     A   B   C   D   a   b   c
# 0 NaN NaN NaN NaN NaN NaN NaN
# 1 NaN NaN NaN NaN NaN NaN NaN
# 2 NaN NaN NaN NaN NaN NaN NaN
# 3 NaN NaN NaN NaN NaN NaN NaN
# 4 NaN NaN NaN NaN NaN NaN NaN
# 5 NaN NaN NaN NaN NaN NaN NaN
# 6 NaN NaN NaN NaN NaN NaN NaN
# 7 NaN NaN NaN NaN NaN NaN NaN
# 8 NaN NaN NaN NaN NaN NaN NaN
# 9 NaN NaN NaN NaN NaN NaN NaN

# %%
df
# Out:
#           A         B         C         D
# 0  0.092496  0.115683  0.428621  0.241810
# 1 -0.735602 -0.459100  0.025895  1.313976
# 2  0.923235  0.014159 -1.334824  0.304555
# 3  1.061694 -0.397518  0.119811 -0.023807
# 4 -1.736165  0.026519 -1.028012  1.023139
# 5 -0.901850 -0.137073 -0.795772 -1.384434
# 6 -2.083395 -0.015289  1.765392 -0.117258
# 7  1.689711  0.820882  1.769265 -0.195206
# 8  1.795859  1.538452 -0.842240 -0.201616
# 9  1.116991 -0.097566  0.124083  0.272482

# %%
df**2
# Out:
#           A         B         C         D
# 0  0.008555  0.013383  0.183716  0.058472
# 1  0.541111  0.210773  0.000671  1.726532
# 2  0.852363  0.000200  1.781756  0.092754
# 3  1.127194  0.158021  0.014355  0.000567
# 4  3.014271  0.000703  1.056810  1.046813
# 5  0.813334  0.018789  0.633253  1.916659
# 6  4.340533  0.000234  3.116609  0.013749
# 7  2.855124  0.673848  3.130300  0.038105
# 8  3.225111  2.366835  0.709367  0.040649
# 9  1.247669  0.009519  0.015397  0.074247

# %%
-0.735602*-0.735602
# Out:
# 0.5411103024039999

# %%
pd.Index([4, 5, 6])
# Out:
# Index([4, 5, 6], dtype='int64')

# %%
df.to_string()
# Out:
# '          A         B         C         D\n0  0.092496  0.115683  0.428621  0.241810\n1 -0.735602 -0.459100  0.025895  1.313976\n2  0.923235  0.014159 -1.334824  0.304555\n3  1.061694 -0.397518  0.119811 -0.023807\n4 -1.736165  0.026519 -1.028012  1.023139\n5 -0.901850 -0.137073 -0.795772 -1.384434\n6 -2.083395 -0.015289  1.765392 -0.117258\n7  1.689711  0.820882  1.769265 -0.195206\n8  1.795859  1.538452 -0.842240 -0.201616\n9  1.116991 -0.097566  0.124083  0.272482'

# %%
pd.DataFrame(
    {
        ("a", "b"): {("A", "B"): 1, ("A", "C"): 2},
        ("a", "a"): {("A", "C"): 3, ("A", "B"): 4},
        ("a", "c"): {("A", "B"): 5, ("A", "C"): 6},
        ("b", "a"): {("A", "C"): 7, ("A", "B"): 8},
        ("b", "b"): {("A", "D"): 9, ("A", "B"): 10},
    }
)
# Out:
#        a              b
#        b    a    c    a     b
# A B  1.0  4.0  5.0  8.0  10.0
#   C  2.0  3.0  6.0  7.0   NaN
#   D  NaN  NaN  NaN  NaN   9.0

# %%
pd.date_range("1/1/2000", periods=8)
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.DataFrame(np.random.randn(70000, 3000))

# %%
# %%timeit
df2 + df2
# Out:
# 297 ms ± 6.17 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
df2.add(df2, fill_value=0)
# Out:
# 672 ms ± 6.13 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
df2 * df2
# Out:
# 296 ms ± 5.91 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
df2.mul(df2, fill_value=0)
# Out:
# 668 ms ± 2.76 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
sum(pd.Series(["foo", "bar", "baz"]) == pd.Index(["foo", "bar", "qux"]))
# Out:
# 2

# %%
df2.combine(df2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df2.combine(df2)
#
# TypeError: combine() missing 1 required positional argument: 'func'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 np.where(pd.isna(df2), df2)
#
# File <__array_function__ internals>:200, in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given

# %%
df2.mean()
# Out:
# 0      -0.006629
# 1       0.006041
# 2      -0.000183
# 3      -0.003594
# 4      -0.003174
#           ...
# 2995    0.000223
# 2996   -0.004461
# 2997    0.002330
# 2998    0.006770
# 2999    0.001594
# Length: 3000, dtype: float64

# %%
df2.count()
# Out:
# 0       70000
# 1       70000
# 2       69999
# 3       70000
# 4       70000
#         ...
# 2995    70000
# 2996    70000
# 2997    70000
# 2998    70000
# 2999    70000
# Length: 3000, dtype: int64

# %%
df2.iloc[1,2] = np.nan

# %%
df2.mode()
# Out:
#            0         1         2         3         4         5         6     \
# 0     -4.457493 -4.223443 -4.024354 -4.567369 -3.898526 -4.704251 -4.516713
# 1     -4.292905 -4.167577 -3.702776 -3.936325 -3.875643 -3.878766 -3.992769
# 2     -4.188909 -4.149669 -3.701911 -3.850235 -3.795017 -3.768107 -3.961642
# 3     -3.967766 -4.046623 -3.685393 -3.849472 -3.759402 -3.745788 -3.934190
# 4     -3.795146 -3.961129 -3.624474 -3.835899 -3.702885 -3.697180 -3.906701
# ...         ...       ...       ...       ...       ...       ...       ...
# 69995  3.843391  3.650616  3.820984  3.931281  3.792762  4.027385  3.869797
# 69996  3.853496  3.762058  3.935231  3.936889  3.836682  4.121524  3.887729
# 69997  3.904188  3.808078  4.115931  3.958381  3.842406  4.128355  3.922498
# 69998  3.967713  4.190719  4.470654  3.996077  3.869117  4.128448  4.005440
# 69999  4.034975  4.426549       NaN  4.022929  4.010224  4.157340  4.121934
#
# ...

# %%
df2 = pd.DataFrame(np.random.randn(50, 5))

# %%
df2.quantile(axis=0)
# Out:
# 0    0.021991
# 1   -0.259121
# 2    0.172550
# 3    0.011200
# 4   -0.110133
# Name: 0.5, dtype: float64

# %%
pd.Series([np.nan, None, 2, 3])
# Out:
# 0    NaN
# 1    NaN
# 2    2.0
# 3    3.0
# dtype: float64

# %%
dir(pd.interpolate())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 dir(pd.interpolate())
#
# AttributeError: module 'pandas' has no attribute 'interpolate'

# %%
help(pd.DataFrame.interpolate)
# Out:
# Help on function interpolate in module pandas.core.frame:
#
# interpolate(self: 'DataFrame', method: 'str' = 'linear', *, axis: 'Axis' = 0, limit: 'int | None' = None, inplace: 'bool' = False, limit_direction: 'str | None' = None, limit_area: 'str | None' = None, downcast: 'str | None' = None, **kwargs) -> 'DataFrame | None'
#     Fill NaN values using an interpolation method.
#
#     Please note that only ``method='linear'`` is supported for
#     DataFrame/Series with a MultiIndex.
#
#     Parameters
#     ----------
#     method : str, default 'linear'
#         Interpolation technique to use. One of:
#
#         * 'linear': Ignore the index and treat the values as equally
#           spaced. This is the only method supported on MultiIndexes.
#         * 'time': Works on daily and higher resolution data to interpolate
#           given length of interval.
#         * 'index', 'values': use the actual numerical values of the index.
# ...

# %%
import pandas as pd
df=pd.DataFrame({'Age':[11,12,13,14,15],'Height':[135,140,138,147,145],'Weight':[35,38,30,45,45]})
print("---------The DataFrame is---------")
print(df)
print("-----------------")
print(df.quantile(0.2 , axis=0))
# Out:
# ---------The DataFrame is---------
#    Age  Height  Weight
# 0   11     135      35
# 1   12     140      38
# 2   13     138      30
# 3   14     147      45
# 4   15     145      45
# -----------------
# Age        11.8
# Height    137.4
# Weight     34.0
# Name: 0.2, dtype: float64

# %%
pd.Series([1,2,3,4,np.nan]).prod()
# Out:
# 24.0

# %%
pd.Series([0.0, np.nan, np.nan, np.nan, 10.0]).interpolate(method="polynomial", order=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 pd.Series([0.0, np.nan, np.nan, np.nan, 10.0]).interpolate(method="polynomial", order=2)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:5942, in Series.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    5930 def interpolate(
#    5931     self: Series,
#    5932     method: str = "linear",
#    (...)
#    5940     **kwargs,
#    5941 ) -> Series | None:
# -> 5942     return super().interpolate(
#    5943         method=method,
#    5944         axis=axis,
#    5945         limit=limit,
#    5946         inplace=inplace,
#    5947         limit_direction=limit_direction,
#    5948         limit_area=limit_area,
#    5949         downcast=downcast,
#    5950         **kwargs,
#    5951     )
#
# ...

# %%
df = pd.DataFrame(
   {
      "A": [1, 2.1, np.nan, 4.7, 5.6, 6.8],
      "B": [0.25, np.nan, np.nan, 4, 12.2, 14.4],
   }
)
df.interpolate(method="polynomial", order=2)
# Out:
#           A          B
# 0  1.000000   0.250000
# 1  2.100000  -2.703846
# 2  3.451351  -1.453846
# 3  4.700000   4.000000
# 4  5.600000  12.200000
# 5  6.800000  14.400000

# %%
df[df.isna()]
# Out:
#     A   B
# 0 NaN NaN
# 1 NaN NaN
# 2 NaN NaN
# 3 NaN NaN
# 4 NaN NaN
# 5 NaN NaN

# %%
pd.Series([np.nan, np.nan, 5, np.nan, np.nan, np.nan, 13, np.nan, np.nan]).interpolate()
# Out:
# 0     NaN
# 1     NaN
# 2     5.0
# 3     7.0
# 4     9.0
# 5    11.0
# 6    13.0
# 7    13.0
# 8    13.0
# dtype: float64

# %%
x = 1+3j
y = 3 - 2j

# %%
x+y
# Out:
# (4+1j)

# %%
x*y
# Out:
# (9+7j)

# %%
# Out:
# False

# %%
{
    frozenset({5 , 5}): 5,
    (1,2,3): 6
}
# Out:
# {frozenset({5}): 5, (1, 2, 3): 6}

# %%
temp = [
    [
        [1,2,3],
        [1,2,3]
    ],
    [
        [1,2,3],
        [1,2,3]
    ]
]

# %%
import copy
xs = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
zs = copy.deepcopy(xs)
mm = copy.copy(xs)

# %%
xs[1][0] = 'X'
xs[0] = [0,0,0]

# %%
zs
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
mm
# Out:
# [[1, 2, 3], ['X', 5, 6], [7, 8, 9]]

# %%
arr = np.random.randn(20)
factor = pd.cut(arr, 4)
factor
# Out:
# [(-0.32, 0.651], (0.651, 1.622], (-0.32, 0.651], (0.651, 1.622], (-2.266, -1.291], ..., (-0.32, 0.651], (-1.291, -0.32], (-0.32, 0.651], (-0.32, 0.651], (-1.291, -0.32]]
# Length: 20
# Categories (4, interval[float64, right]): [(-2.266, -1.291] < (-1.291, -0.32] < (-0.32, 0.651] < (0.651, 1.622]]

# %%
arr
# Out:
# array([-0.07283368,  0.7042028 ,  0.65036277,  1.62218096, -2.26234676,
#         0.7629679 , -0.3150704 , -1.08959444, -0.39258056, -0.72505324,
#        -0.16633658, -0.01887659, -0.80505506, -0.11161983,  1.10831475,
#         0.49810446, -0.48484093,  0.04048433,  0.12837912, -0.89312761])

# %%
def func(x):
    return x>5

temp = [1,2,3,4,5,7,8,9,10]
